# %%
import pandas as pd
df = pd.read_csv('final_dataset_shuffled.csv')
df
# Out:
#          genre       interpret                                     album  \
# 0          Pop            Nena                                  Cover Me
# 1     Schlager  Helene Fischer                    Von hier bis unendlich
# 2          Pop   Max Giesinger                      Der Junge, der rennt
# 3     Schlager     Udo Jürgens               Willkommen In Meinem Leben
# 4          Pop  Annett Louisan                       Zu Viel Information
# ...        ...             ...                                       ...
# 4630      Rock       Die Ärzte  Das Beste von kurz nach früher bis jetze
# 4631  Schlager       Roy Black                                 Roy Black
# 4632       Rap     Fettes Brot                           Strom Und Drang
# 4633      Rock       Die Ärzte                     Im Schatten der Ärzte
# 4634       Rap             Cro                                     Sunny
#
#       release_year                     songtitle  decade  song_id  \
# ...

# %%
df = df[df['lyrics'].notna()]

# %%
df
# Out:
#          genre       interpret                                     album  \
# 0          Pop            Nena                                  Cover Me
# 1     Schlager  Helene Fischer                    Von hier bis unendlich
# 2          Pop   Max Giesinger                      Der Junge, der rennt
# 3     Schlager     Udo Jürgens               Willkommen In Meinem Leben
# 4          Pop  Annett Louisan                       Zu Viel Information
# ...        ...             ...                                       ...
# 4630      Rock       Die Ärzte  Das Beste von kurz nach früher bis jetze
# 4631  Schlager       Roy Black                                 Roy Black
# 4632       Rap     Fettes Brot                           Strom Und Drang
# 4633      Rock       Die Ärzte                     Im Schatten der Ärzte
# 4634       Rap             Cro                                     Sunny
#
#       release_year                     songtitle  decade  song_id  \
# ...

# %%
df = df[df['lyrics'].notnull()]

# %%
df
# Out:
#          genre       interpret                                     album  \
# 0          Pop            Nena                                  Cover Me
# 1     Schlager  Helene Fischer                    Von hier bis unendlich
# 2          Pop   Max Giesinger                      Der Junge, der rennt
# 3     Schlager     Udo Jürgens               Willkommen In Meinem Leben
# 4          Pop  Annett Louisan                       Zu Viel Information
# ...        ...             ...                                       ...
# 4630      Rock       Die Ärzte  Das Beste von kurz nach früher bis jetze
# 4631  Schlager       Roy Black                                 Roy Black
# 4632       Rap     Fettes Brot                           Strom Und Drang
# 4633      Rock       Die Ärzte                     Im Schatten der Ärzte
# 4634       Rap             Cro                                     Sunny
#
#       release_year                     songtitle  decade  song_id  \
# ...

# %%
df = df[df['lyrics'] != 'None']

# %%
df
# Out:
#          genre       interpret                                     album  \
# 0          Pop            Nena                                  Cover Me
# 1     Schlager  Helene Fischer                    Von hier bis unendlich
# 2          Pop   Max Giesinger                      Der Junge, der rennt
# 3     Schlager     Udo Jürgens               Willkommen In Meinem Leben
# 4          Pop  Annett Louisan                       Zu Viel Information
# ...        ...             ...                                       ...
# 4630      Rock       Die Ärzte  Das Beste von kurz nach früher bis jetze
# 4631  Schlager       Roy Black                                 Roy Black
# 4632       Rap     Fettes Brot                           Strom Und Drang
# 4633      Rock       Die Ärzte                     Im Schatten der Ärzte
# 4634       Rap             Cro                                     Sunny
#
#       release_year                     songtitle  decade  song_id  \
# ...

# %%
df.to_csv('final_dataset_shuffled_lyrics.csv', index=False)

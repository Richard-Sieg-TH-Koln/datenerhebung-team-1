# %%
import pandas as pd

# %%
df1 = pd.read_csv('metadata_run.csv')
df2 = pd.read_csv('metadata_run_2.csv')
df3 = pd.read_csv('metadata_run_3.csv')
df4 = pd.read_csv('metadata_run_4.csv')
df5 = pd.read_csv('metadata_run_5.csv')
df6 = pd.read_csv('metadata_run_6.csv')
df7 = pd.read_csv('metadata_run_7.csv')
df8 = pd.read_csv('metadata_run_8.csv')
df9 = pd.read_csv('metadata_run_9.csv')
df10 = pd.read_csv('metadata_run_10.csv')

# %%
dataframes = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]

# Concatenate the DataFrames using pd.concat
merged_df = pd.concat(dataframes)

# Reset the index of the merged DataFrame
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 5166  2raumwohnung      Sie kann fliegen                      NaN       de
# 5167  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 5168  2raumwohnung     Wir werden singen                      NaN       de
# 5169  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 5170  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
merged_df.to_csv('new_songs.csv')

# %%
import pandas as pd
df = pd.read_csv('new_songs.csv')

# %%
df
# Out:
#       Unnamed: 0        artist                  song release_date_for_display
# 0              0    Adel Tawil               Fenster           April 28, 2023  \
# 1              1    Adel Tawil          Venus & Mars            March 3, 2023
# 2              2    Adel Tawil           Spiegelbild            March 3, 2023
# 3              3    Adel Tawil               Nirvana            March 3, 2023
# 4              4    Adel Tawil              Leuchten            March 3, 2023
# ...          ...           ...                   ...                      ...
# 5166        5166  2raumwohnung      Sie kann fliegen                      NaN
# 5167        5167  2raumwohnung    Sasha (Sex Secret)                      NaN
# 5168        5168  2raumwohnung     Wir werden singen                      NaN
# 5169        5169  2raumwohnung  Wolken ziehen vorbei                      NaN
# 5170        5170  2raumwohnung             Spiel mit                      NaN
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 5166  2raumwohnung      Sie kann fliegen                      NaN       de
# 5167  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 5168  2raumwohnung     Wir werden singen                      NaN       de
# 5169  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 5170  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
duplicates = df[df['full_title'].duplicated()]
# duplicates = df[df['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
#               artist                                             song
# 748         Beginner                                       Nach Hause  \
# 749         Beginner                                            Kater
# 750         Beginner                                    Thomas Anders
# 751         Beginner                                             Spam
# 752         Beginner                                       Foxy Music
# ...              ...                                              ...
# 5140  Annett Louisan                       Somewhere Over The Rainbow
# 5141  Annett Louisan                            Nights In White Satin
# 5142  Annett Louisan                                          Reality
# 5143  Annett Louisan                                             Torn
# 5144  Annett Louisan  Die schönsten Wege sind aus Holz (Kleine Liebe)
#
#      release_date_for_display language
# 748           August 26, 2016       de  \
# 749           August 26, 2016       de
# ...

# %%
df = df.drop_duplicates(subset=['song_id'], keep='first')

# %%
# duplicates = df[df['full_title'].duplicated()]
# duplicates = df[df['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [artist, song, release_date_for_display, language, stats, release_date_components, full_title, song_id, lyrics]
# Index: []

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 5166  2raumwohnung      Sie kann fliegen                      NaN       de
# 5167  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 5168  2raumwohnung     Wir werden singen                      NaN       de
# 5169  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 5170  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df['lyrics'] = df['lyrics'].str.replace('\n', ' ')
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_7704\3672213528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lyrics'] = df['lyrics'].str.replace('\n', ' ')

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 5166  2raumwohnung      Sie kann fliegen                      NaN       de
# 5167  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 5168  2raumwohnung     Wir werden singen                      NaN       de
# 5169  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 5170  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df['lyrics'] = df['lyrics'].str.replace(r'^.*Lyrics', '', regex=True)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_7704\407730101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lyrics'] = df['lyrics'].str.replace(r'^.*Lyrics', '', regex=True)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 5166  2raumwohnung      Sie kann fliegen                      NaN       de
# 5167  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 5168  2raumwohnung     Wir werden singen                      NaN       de
# 5169  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 5170  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.to_csv('new_songs_v2.csv')

# %%
import pandas as pd
df = pd.read_csv('new_songs_v2.csv', sep=',')

# %%
df
# Out:
#       Unnamed: 0        artist                  song release_date_for_display
# 0              0    Adel Tawil               Fenster           April 28, 2023  \
# 1              1    Adel Tawil          Venus & Mars            March 3, 2023
# 2              2    Adel Tawil           Spiegelbild            March 3, 2023
# 3              3    Adel Tawil               Nirvana            March 3, 2023
# 4              4    Adel Tawil              Leuchten            March 3, 2023
# ...          ...           ...                   ...                      ...
# 4778        5166  2raumwohnung      Sie kann fliegen                      NaN
# 4779        5167  2raumwohnung    Sasha (Sex Secret)                      NaN
# 4780        5168  2raumwohnung     Wir werden singen                      NaN
# 4781        5169  2raumwohnung  Wolken ziehen vorbei                      NaN
# 4782        5170  2raumwohnung             Spiel mit                      NaN
#
# ...

# %%
df
# Out:
#       Unnamed: 0        artist                  song release_date_for_display
# 0              0    Adel Tawil               Fenster           April 28, 2023  \
# 1              1    Adel Tawil          Venus & Mars            March 3, 2023
# 2              2    Adel Tawil           Spiegelbild            March 3, 2023
# 3              3    Adel Tawil               Nirvana            March 3, 2023
# 4              4    Adel Tawil              Leuchten            March 3, 2023
# ...          ...           ...                   ...                      ...
# 4778        5166  2raumwohnung      Sie kann fliegen                      NaN
# 4779        5167  2raumwohnung    Sasha (Sex Secret)                      NaN
# 4780        5168  2raumwohnung     Wir werden singen                      NaN
# 4781        5169  2raumwohnung  Wolken ziehen vorbei                      NaN
# 4782        5170  2raumwohnung             Spiel mit                      NaN
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
# Assuming you have a DataFrame called 'df' and a column named 'release_date_for_display'
df['release_year'] = pd.to_datetime(df['release_date_for_display'], errors='coerce').dt.year.astype('Int64')

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.release_year.sort_values().unique()
# Out:
# <IntegerArray>
# [1922, 1969, 1971, 1976, 1981, 1983, 1984, 1985, 1991, 1994, 1995, 1996, 1997,
#  1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#  2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#  2024, <NA>]
# Length: 41, dtype: Int64

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df['lyrics'] = df['lyrics'].str.replace('embed', '', case=False)
df['lyrics'] = df['lyrics'].str.replace('-Folg RapGeniusDeutschland!', '', case=False)
df['lyrics'] = df['lyrics'].str.replace('Folg RapGeniusDeutschland!', '', case=False)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.to_csv('new_songs_v3.csv', index=False)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.artist.sort_values().unique()
# Out:
# array(['01099', '18 Karat', '187 Straßenbande', '257ers', '2raumwohnung',
#        'ARY', 'Absolute Beginner', 'Adel Tawil', 'Alligatoah',
#        'Andrea Berg', 'Andreas Bourani', 'Andreas Gabalier',
#        'AnnenMayKantereit', 'Annett Louisan', 'Antilopen Gang',
#        'Apache 207', 'Asche', 'Azad', 'Azet', 'BHZ', 'BRKN',
#        'Bass Sultan Hengzt', 'Bausa', 'Bela B', 'Bizzy Montana', 'Bosse',
#        'Broilers', 'Bushido', 'Capital Bra', 'Capo', 'Casper',
#        'Celo & Abdi', 'Chakuza', 'Christian Anders', 'Clueso',
#        'Costa Cordalis', 'Cro', 'Culcha Candela', 'D-Bo', 'DCVDNS',
#        'DJ Tomekk', 'Dardan', 'Deichkind', 'Dendemann',
#        'Die Fantastischen Vier', 'Die Prinzen', 'Die Ärzte',
#        'Dieter Thomas Kuhn', 'Doktor', 'Eddin', 'Edo Saiya',
#        'Edwin Rosen', 'Eko Fresh', 'FOURTY', 'Farid Bang', 'Favorite',
#        'Feine Sahne Fischfilet', 'Fettes Brot', 'Fler', 'Frauenarzt',
#        'Frittenbude', 'Fünf Sterne Deluxe', 'Genetikk',
# ...

# %%
df.describe()
# Out:
#             song_id  release_year
# count  4.783000e+03        4367.0
# mean   5.467494e+06   2019.043279
# std    2.511988e+06        4.7948
# min    1.669000e+03        1922.0
# 25%    3.613178e+06        2018.0
# 50%    6.038892e+06        2020.0
# 75%    7.508536e+06        2022.0
# max    9.154209e+06        2024.0

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df['lyrics'] = df['lyrics'].str.replace('\d+', '', regex=True)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.to_csv('new_songs_v4.csv', index=False)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df['lyrics'] = df['lyrics'].str.replace('"', '', regex=True)

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.to_csv('new_songs_v5.csv', index=False)

# %%
df['lyrics'] = df['lyrics'].str.replace('"', '')

# %%
df
# Out:
#             artist                  song release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                             stats
# ...

# %%
df.to_csv('new_songs_v6.csv', index=False)

# %%
df = df.rename(columns={'artist': 'interpret'})
df = df.rename(columns={'song': 'songtitle'})
df = df.rename(columns={'stats': 'stats_raw'})

# %%
df
# Out:
#          interpret             songtitle release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                         stats_raw
# ...

# %%
df = df.rename(columns={'release_date_components': 'release_date_components_raw'})
df['genre'] = np.nan
df['album'] = np.nan
df['decade'] = np.nan

# %%
df
# Out:
#          interpret             songtitle release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                         stats_raw
# ...

# %%
df["language"].describe()
# Out:
# count     4757
# unique      22
# top         de
# freq      4135
# Name: language, dtype: object

# %%
df.language.sort_values().unique()
# Out:
# array(['cs', 'da', 'de', 'el', 'en', 'es', 'eu', 'fa', 'fi', 'fr', 'gd',
#        'it', 'nl', 'pl', 'ro', 'ru', 'sk', 'sq', 'su', 'sv', 'tr', 'xh',
#        nan], dtype=object)

# %%
df = df[df['language'] == 'de']

# %%
df
# Out:
#          interpret             songtitle release_date_for_display language
# 0       Adel Tawil               Fenster           April 28, 2023       de  \
# 1       Adel Tawil          Venus & Mars            March 3, 2023       de
# 2       Adel Tawil           Spiegelbild            March 3, 2023       de
# 3       Adel Tawil               Nirvana            March 3, 2023       de
# 4       Adel Tawil              Leuchten            March 3, 2023       de
# ...            ...                   ...                      ...      ...
# 4778  2raumwohnung      Sie kann fliegen                      NaN       de
# 4779  2raumwohnung    Sasha (Sex Secret)                      NaN       de
# 4780  2raumwohnung     Wir werden singen                      NaN       de
# 4781  2raumwohnung  Wolken ziehen vorbei                      NaN       de
# 4782  2raumwohnung             Spiel mit                      NaN       de
#
#                                         stats_raw
# ...

# %%
df["language"].describe()
# Out:
# count     4135
# unique       1
# top         de
# freq      4135
# Name: language, dtype: object

# %%
df = df.drop('language', axis=1)
df = df[['genre', 'interpret', 'album', 'release_year', 'songtitle', 'decade', 'song_id', 'full_title', 'release_date_components_raw', 'release_date_for_display', 'stats_raw', 'lyrics']]

# %%
df
# Out:
#       genre     interpret  album  release_year             songtitle  decade
# 0       NaN    Adel Tawil    NaN          2023               Fenster     NaN  \
# 1       NaN    Adel Tawil    NaN          2023          Venus & Mars     NaN
# 2       NaN    Adel Tawil    NaN          2023           Spiegelbild     NaN
# 3       NaN    Adel Tawil    NaN          2023               Nirvana     NaN
# 4       NaN    Adel Tawil    NaN          2023              Leuchten     NaN
# ...     ...           ...    ...           ...                   ...     ...
# 4778    NaN  2raumwohnung    NaN          <NA>      Sie kann fliegen     NaN
# 4779    NaN  2raumwohnung    NaN          <NA>    Sasha (Sex Secret)     NaN
# 4780    NaN  2raumwohnung    NaN          <NA>     Wir werden singen     NaN
# 4781    NaN  2raumwohnung    NaN          <NA>  Wolken ziehen vorbei     NaN
# 4782    NaN  2raumwohnung    NaN          <NA>             Spiel mit     NaN
#
# ...

# %%
# Convert 'release_date_for_display' to datetime
df['release_date_for_display'] = pd.to_datetime(df['release_date_for_display'], errors='coerce')

# Extract the weekday and store it in a new column 'weekday'
df['weekday'] = df['release_date_for_display'].dt.day_name()

# %%
df
# Out:
#       genre     interpret  album  release_year             songtitle  decade
# 0       NaN    Adel Tawil    NaN          2023               Fenster     NaN  \
# 1       NaN    Adel Tawil    NaN          2023          Venus & Mars     NaN
# 2       NaN    Adel Tawil    NaN          2023           Spiegelbild     NaN
# 3       NaN    Adel Tawil    NaN          2023               Nirvana     NaN
# 4       NaN    Adel Tawil    NaN          2023              Leuchten     NaN
# ...     ...           ...    ...           ...                   ...     ...
# 4778    NaN  2raumwohnung    NaN          <NA>      Sie kann fliegen     NaN
# 4779    NaN  2raumwohnung    NaN          <NA>    Sasha (Sex Secret)     NaN
# 4780    NaN  2raumwohnung    NaN          <NA>     Wir werden singen     NaN
# 4781    NaN  2raumwohnung    NaN          <NA>  Wolken ziehen vorbei     NaN
# 4782    NaN  2raumwohnung    NaN          <NA>             Spiel mit     NaN
#
# ...

# %%
df.to_csv('new_songs_v7.csv', index=False)

# %%
df = pd.read_csv('new_songs_v7.csv')

# %%
df
# Out:
#       genre     interpret  album  release_year             songtitle  decade
# 0       NaN    Adel Tawil    NaN        2023.0               Fenster     NaN  \
# 1       NaN    Adel Tawil    NaN        2023.0          Venus & Mars     NaN
# 2       NaN    Adel Tawil    NaN        2023.0           Spiegelbild     NaN
# 3       NaN    Adel Tawil    NaN        2023.0               Nirvana     NaN
# 4       NaN    Adel Tawil    NaN        2023.0              Leuchten     NaN
# ...     ...           ...    ...           ...                   ...     ...
# 4130    NaN  2raumwohnung    NaN           NaN      Sie kann fliegen     NaN
# 4131    NaN  2raumwohnung    NaN           NaN    Sasha (Sex Secret)     NaN
# 4132    NaN  2raumwohnung    NaN           NaN     Wir werden singen     NaN
# 4133    NaN  2raumwohnung    NaN           NaN  Wolken ziehen vorbei     NaN
# 4134    NaN  2raumwohnung    NaN           NaN             Spiel mit     NaN
#
# ...

# %%
import pandas as pd
import spacy

nlp = spacy.load('de_core_news_sm')

def is_word(token):
    return not token.is_stop and not token.is_punct and not token.is_space

def count_words(text):
    doc = nlp(text)
    return len([token for token in doc if is_word(token)])

df['word_count'] = df['lyrics'].apply(lambda x: count_words(x))

print(df)
# Out:
#       genre     interpret  album  release_year             songtitle  decade
# 0       NaN    Adel Tawil    NaN        2023.0               Fenster     NaN  \
# 1       NaN    Adel Tawil    NaN        2023.0          Venus & Mars     NaN
# 2       NaN    Adel Tawil    NaN        2023.0           Spiegelbild     NaN
# 3       NaN    Adel Tawil    NaN        2023.0               Nirvana     NaN
# 4       NaN    Adel Tawil    NaN        2023.0              Leuchten     NaN
# ...     ...           ...    ...           ...                   ...     ...
# 4130    NaN  2raumwohnung    NaN           NaN      Sie kann fliegen     NaN
# 4131    NaN  2raumwohnung    NaN           NaN    Sasha (Sex Secret)     NaN
# 4132    NaN  2raumwohnung    NaN           NaN     Wir werden singen     NaN
# 4133    NaN  2raumwohnung    NaN           NaN  Wolken ziehen vorbei     NaN
# 4134    NaN  2raumwohnung    NaN           NaN             Spiel mit     NaN
#
# ...

# %%
df
# Out:
#       genre     interpret  album  release_year             songtitle  decade
# 0       NaN    Adel Tawil    NaN        2023.0               Fenster     NaN  \
# 1       NaN    Adel Tawil    NaN        2023.0          Venus & Mars     NaN
# 2       NaN    Adel Tawil    NaN        2023.0           Spiegelbild     NaN
# 3       NaN    Adel Tawil    NaN        2023.0               Nirvana     NaN
# 4       NaN    Adel Tawil    NaN        2023.0              Leuchten     NaN
# ...     ...           ...    ...           ...                   ...     ...
# 4130    NaN  2raumwohnung    NaN           NaN      Sie kann fliegen     NaN
# 4131    NaN  2raumwohnung    NaN           NaN    Sasha (Sex Secret)     NaN
# 4132    NaN  2raumwohnung    NaN           NaN     Wir werden singen     NaN
# 4133    NaN  2raumwohnung    NaN           NaN  Wolken ziehen vorbei     NaN
# 4134    NaN  2raumwohnung    NaN           NaN             Spiel mit     NaN
#
# ...

# %%
df.word_count.describe()
# Out:
# count    4135.000000
# mean      158.735187
# std       110.091200
# min         3.000000
# 25%        96.000000
# 50%       148.000000
# 75%       204.000000
# max      4006.000000
# Name: word_count, dtype: float64

# %%
df2 = pd.read_csv('dataset_cleaned_file_v5.csv')

# %%
df_union = pd.concat([df, df2])

# %%
df_union
# Out:
#          genre       interpret                 album  release_year
# 0          NaN      Adel Tawil                   NaN        2023.0  \
# 1          NaN      Adel Tawil                   NaN        2023.0
# 2          NaN      Adel Tawil                   NaN        2023.0
# 3          NaN      Adel Tawil                   NaN        2023.0
# 4          NaN      Adel Tawil                   NaN        2023.0
# ...        ...             ...                   ...           ...
# 4187  Schlager  Wolfgang Petry            Achterbahn        2001.0
# 4188  Schlager  Wolfgang Petry            Achterbahn        2001.0
# 4189  Schlager  Wolfgang Petry            Achterbahn        2001.0
# 4190  Schlager  Wolfgang Petry  Kein Grund zur Panik        2003.0
# 4191  Schlager  Wolfgang Petry  Kein Grund zur Panik        2003.0
#
#                              songtitle  decade  song_id
# 0                              Fenster     NaN  9061124  \
# ...

# %%
fill_value = 0
df_union['release_year'] = df_union['release_year'].fillna(fill_value)
df_union['release_year'] = df_union['release_year'].astype(int)

df_union['decade'] = df_union['decade'].fillna(fill_value)
df_union['decade'] = df_union['decade'].astype(int)

# %%
df_union
# Out:
#          genre       interpret                 album  release_year
# 0          NaN      Adel Tawil                   NaN          2023  \
# 1          NaN      Adel Tawil                   NaN          2023
# 2          NaN      Adel Tawil                   NaN          2023
# 3          NaN      Adel Tawil                   NaN          2023
# 4          NaN      Adel Tawil                   NaN          2023
# ...        ...             ...                   ...           ...
# 4187  Schlager  Wolfgang Petry            Achterbahn          2001
# 4188  Schlager  Wolfgang Petry            Achterbahn          2001
# 4189  Schlager  Wolfgang Petry            Achterbahn          2001
# 4190  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4191  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                              Fenster       0  9061124  \
# ...

# %%
duplicates = df_union[df_union['full_title'].duplicated()]
# duplicates = df[df['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
#          genre        interpret  album  release_year
# 14         Pop  Andreas Bourani    Hey          2014  \
# 15         Pop  Andreas Bourani    Hey          2014
# 16         Pop  Andreas Bourani    Hey          2014
# 17         Pop  Andreas Bourani    Hey          2014
# 19         Pop  Andreas Bourani    Hey          2014
# ...        ...              ...    ...           ...
# 4152  Schlager   Wolfgang Petry  Alles          1996
# 4153  Schlager   Wolfgang Petry  Alles          1996
# 4155  Schlager   Wolfgang Petry  Alles          1996
# 4156  Schlager   Wolfgang Petry  Alles          1996
# 4157  Schlager   Wolfgang Petry  Alles          1996
#
#                        songtitle  decade  song_id
# 14               Wieder am Leben    2010  2258550  \
# 15                       Auf uns    2010   447075
# 16              Alles beim Alten    2010   917198
# 17                           Hey    2010  1195808
# 19               Nimm meine Hand    2010  2258904
# ...

# %%
#duplicates = df_union[df_union['full_title'].duplicated()]
duplicates = df_union[df_union['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
#          genre        interpret  album  release_year
# 14         Pop  Andreas Bourani    Hey          2014  \
# 15         Pop  Andreas Bourani    Hey          2014
# 16         Pop  Andreas Bourani    Hey          2014
# 17         Pop  Andreas Bourani    Hey          2014
# 19         Pop  Andreas Bourani    Hey          2014
# ...        ...              ...    ...           ...
# 4152  Schlager   Wolfgang Petry  Alles          1996
# 4153  Schlager   Wolfgang Petry  Alles          1996
# 4155  Schlager   Wolfgang Petry  Alles          1996
# 4156  Schlager   Wolfgang Petry  Alles          1996
# 4157  Schlager   Wolfgang Petry  Alles          1996
#
#                        songtitle  decade  song_id
# 14               Wieder am Leben    2010  2258550  \
# 15                       Auf uns    2010   447075
# 16              Alles beim Alten    2010   917198
# 17                           Hey    2010  1195808
# 19               Nimm meine Hand    2010  2258904
# ...

# %%
duplicates_sub = df_union.duplicated(subset=['interpret', 'songtitle']).any()
print(duplicates_sub)
# Out:
# True

# %%
df = df_union.drop_duplicates(subset=['song_id'], keep='first')

# %%
df
# Out:
#          genre       interpret                 album  release_year
# 0          NaN      Adel Tawil                   NaN          2023  \
# 1          NaN      Adel Tawil                   NaN          2023
# 2          NaN      Adel Tawil                   NaN          2023
# 3          NaN      Adel Tawil                   NaN          2023
# 4          NaN      Adel Tawil                   NaN          2023
# ...        ...             ...                   ...           ...
# 4187  Schlager  Wolfgang Petry            Achterbahn          2001
# 4188  Schlager  Wolfgang Petry            Achterbahn          2001
# 4189  Schlager  Wolfgang Petry            Achterbahn          2001
# 4190  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4191  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                              Fenster       0  9061124  \
# ...

# %%
df.to_csv('dataset_cleaned_file_v6.csv', index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_cleaned_file_v3.csv')
df
# Out:
#          genre       interpret                 album  release_year  \
# 0          Pop      Adel Tawil                Lieder          2013
# 1          Pop      Adel Tawil                Lieder          2013
# 2          Pop      Adel Tawil                Lieder          2013
# 3          Pop      Adel Tawil                Lieder          2013
# 4          Pop      Adel Tawil                Lieder          2013
# ...        ...             ...                   ...           ...
# 4537  Schlager  Wolfgang Petry            Achterbahn          2001
# 4538  Schlager  Wolfgang Petry            Achterbahn          2001
# 4539  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4540  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4541  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id  \
# 0                             Immer da    2010   256740
# ...

# %%
df['lyrics']
# Out:
# 0         Manchmal hast du gar nichts mehr Nur noch de...
# 1        Ganz allein im schwarzen Licht wie hinter Gla...
# 2         Ich ging wie ein Ägypter Hab' mit Tauben gew...
# 3         Du warst die ganze Welt für mich Warst das, ...
# 4         Keine Chance, es ist viel zu tief Keine Chan...
#                               ...
# 4537     Du wolltest deine Freiheit haben Nun stehst d...
# 4538     Wenn die Sonne untergeht in der Provinz, ho h...
# 4539    Wolfgang Petry - Anfang Vom Ende Lyrics Briefe...
# 4540                                                 E...
# 4541     Der Albtraum, dem ich entstamme, steht auf Fü...
# Name: lyrics, Length: 4542, dtype: object

# %%
weird_words = df.loc[df['lyrics'].str.contains("Embed", case=True)]

# %%
print(weird_words)
# Out:
#          genre       interpret                 album  release_year  \
# 1          Pop      Adel Tawil                Lieder          2013
# 2          Pop      Adel Tawil                Lieder          2013
# 3          Pop      Adel Tawil                Lieder          2013
# 5          Pop      Adel Tawil                Lieder          2013
# 6          Pop      Adel Tawil                Lieder          2013
# ...        ...             ...                   ...           ...
# 4527  Schlager  Wolfgang Petry               Konkret          2000
# 4528  Schlager  Wolfgang Petry            Achterbahn          2001
# 4530  Schlager  Wolfgang Petry            Achterbahn          2001
# 4533  Schlager  Wolfgang Petry            Achterbahn          2001
# 4541  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                  songtitle  decade  song_id  \
# 1           Wenn Du liebst    2010   256742
# 2                   Lieder    2010   236655
# ...

# %%
# remove Embed
df['lyrics'] = df['lyrics'].str.replace('Embed', '')

# %%
df['lyrics']
# Out:
# 0         Manchmal hast du gar nichts mehr Nur noch de...
# 1        Ganz allein im schwarzen Licht wie hinter Gla...
# 2         Ich ging wie ein Ägypter Hab' mit Tauben gew...
# 3         Du warst die ganze Welt für mich Warst das, ...
# 4         Keine Chance, es ist viel zu tief Keine Chan...
#                               ...
# 4537     Du wolltest deine Freiheit haben Nun stehst d...
# 4538     Wenn die Sonne untergeht in der Provinz, ho h...
# 4539    Wolfgang Petry - Anfang Vom Ende Lyrics Briefe...
# 4540                                                 E...
# 4541     Der Albtraum, dem ich entstamme, steht auf Fü...
# Name: lyrics, Length: 4542, dtype: object

# %%
df.to_csv('1_lyrics.csv', index=False)

# %%
#remove "You might also like" phrase
df['lyrics'] = df['lyrics'].str.replace('You might also like', '')

# %%
#remove "Werde Teil der Genius Community"
df['lyrics'] = df['lyrics'].str.replace('Werde Teil der Genius-Deutschland-Community!', '')

# %%
weird_words = df.loc[df['lyrics'].str.contains("Embed", case=True)]
you_might = df.loc[df['lyrics'].str.contains("You might also", case=True)]

# %%
print(weird_words)
# Out:
# Empty DataFrame
# Columns: [genre, interpret, album, release_year, songtitle, decade, song_id, full_title, release_date_components_raw, release_date_for_display, stats_raw, lyrics]
# Index: []

# %%
print(you_might)
# Out:
# Empty DataFrame
# Columns: [genre, interpret, album, release_year, songtitle, decade, song_id, full_title, release_date_components_raw, release_date_for_display, stats_raw, lyrics]
# Index: []

# %%
df.to_csv('2_lyrics.csv', index=False)

# %%
#remove "Werde Teil der Rock Community"
df['lyrics'] = df['lyrics'].str.replace('Werd Teil der Rock Genius-Community!', '')

# %%
rock_community = df.loc[df['lyrics'].str.contains("Werd Teil der Rock", case=True)]

# %%
rock_community
# Out:
# Empty DataFrame
# Columns: [genre, interpret, album, release_year, songtitle, decade, song_id, full_title, release_date_components_raw, release_date_for_display, stats_raw, lyrics]
# Index: []

# %%
df.to_csv('3_lyrics.csv', index=False)

# %%
#remove "Werde Teil der Rock Community"
df['lyrics'] = df['lyrics'].str.replace('Werd Teil der RGD-Community!', '')

# %%
rgd = df.loc[df['lyrics'].str.contains("Werd Teil der RGD-Community", case=True)]

# %%
rgd
# Out:
# Empty DataFrame
# Columns: [genre, interpret, album, release_year, songtitle, decade, song_id, full_title, release_date_components_raw, release_date_for_display, stats_raw, lyrics]
# Index: []

# %%
df.to_csv('3_lyrics.csv', index=False)

# %%
df['lyrics'] = df['lyrics'].str.replace('Folg RapGeniusDeutschland!', '')
df['lyrics'] = df['lyrics'].str.replace('Rap Genius Deutschland!', '')
df['lyrics'] = df['lyrics'].str.replace('-RapGeniusDeutschland', '')

# %%
df.to_csv('4_lyrics.csv', index=False)

# %%
df['lyrics'] = df['lyrics'].str.replace('-Folg RapGeniusDeutschland und beteilige dich aktiv an der Community!', '')

# %%
df.to_csv('5_lyrics.csv', index=False)

# %%
df['lyrics'] = df['lyrics'].str.replace('-Texte und Deutung von RapGeniusDeutschland', '')
df['lyrics'] = df['lyrics'].str.replace('RapGeniusDeutschland', '')

# %%
df['lyrics'] = df['lyrics'].str.replace('geniusde', '')

# %%
df.to_csv('5_lyrics.csv', index=False)

# %%
df['lyrics'] = df['lyrics'].str.replace('Rap Genius Deutschland', '')
df['lyrics'] = df['lyrics'].str.replace(' Rap Genius Deutschland', '')

# %%
df.to_csv('5_lyrics.csv', index=False)

# %%
#remove all numbers from lyrics column
df['lyrics'] = df['lyrics'].str.replace('\d+', '', regex=True)

# %%
df.to_csv('lyrics_check.csv', index=False)

# %%
df.dropna(subset=['lyrics'], inplace=True)

# %%
df
# Out:
#          genre       interpret                 album  release_year  \
# 0          Pop      Adel Tawil                Lieder          2013
# 1          Pop      Adel Tawil                Lieder          2013
# 2          Pop      Adel Tawil                Lieder          2013
# 3          Pop      Adel Tawil                Lieder          2013
# 4          Pop      Adel Tawil                Lieder          2013
# ...        ...             ...                   ...           ...
# 4537  Schlager  Wolfgang Petry            Achterbahn          2001
# 4538  Schlager  Wolfgang Petry            Achterbahn          2001
# 4539  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4540  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4541  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id  \
# 0                             Immer da    2010   256740
# ...

# %%
df.to_csv('lyrics_check.csv', index=False)

# %%
#add weekday to dataset
df['release_date_for_display'] = pd.to_datetime(df['release_date_for_display'])
df['weekday'] = df['release_date_for_display'].dt.day_name()

# %%
df
# Out:
#          genre       interpret                 album  release_year  \
# 0          Pop      Adel Tawil                Lieder          2013
# 1          Pop      Adel Tawil                Lieder          2013
# 2          Pop      Adel Tawil                Lieder          2013
# 3          Pop      Adel Tawil                Lieder          2013
# 4          Pop      Adel Tawil                Lieder          2013
# ...        ...             ...                   ...           ...
# 4537  Schlager  Wolfgang Petry            Achterbahn          2001
# 4538  Schlager  Wolfgang Petry            Achterbahn          2001
# 4539  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4540  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4541  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id  \
# 0                             Immer da    2010   256740
# ...

# %%
df.to_csv('dataset_cleaned_file_v4.csv', index=False)

# %%
df
# Out:
#          genre       interpret                 album  release_year  \
# 0          Pop      Adel Tawil                Lieder          2013
# 1          Pop      Adel Tawil                Lieder          2013
# 2          Pop      Adel Tawil                Lieder          2013
# 3          Pop      Adel Tawil                Lieder          2013
# 4          Pop      Adel Tawil                Lieder          2013
# ...        ...             ...                   ...           ...
# 4537  Schlager  Wolfgang Petry            Achterbahn          2001
# 4538  Schlager  Wolfgang Petry            Achterbahn          2001
# 4539  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4540  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 4541  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id  \
# 0                             Immer da    2010   256740
# ...

# %%
import csv
import lyricsgenius
token = "aCR_2MFW9c27A8yjxOWlsCfqywd5w1KzwBZJMqncj4psGS0pPdcGzIv05TfkrKIG"
genius = lyricsgenius.Genius(token, remove_section_headers=True, timeout=10000, retries=5)

# %%
with open('all.csv', 'r', newline='', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    data = list(reader)

# %%
for row in data:
    song = genius.search_song(row['songtitle'], artist=row['interpret'])
    if song:
        row['lyrics'] = song.lyrics
# Out:
# Searching for "Immer da" by Adel Tawil...
# Done.
# Searching for "Wenn Du liebst" by Adel Tawil...
# Done.
# Searching for "Lieder" by Adel Tawil...
# Done.
# Searching for "Weinen" by Adel Tawil...
# Done.
# Searching for "Unter Wasser" by Adel Tawil...
# Done.
# Searching for "Kartenhaus" by Adel Tawil...
# Done.
# Searching for "Aschenflug" by Adel Tawil...
# Done.
# Searching for "Zuhause" by Adel Tawil...
# Done.
# Searching for "Herzschrittmacher" by Adel Tawil...
# Done.
# Searching for "Graffiti Love" by Adel Tawil...
# Done.
# Searching for "Auf Sand gebaut" by Adel Tawil...
# Done.
# Searching for "Schnee" by Adel Tawil...
# Done.
# Searching for "Dunkelheit" by Adel Tawil...
# Done.
# Searching for "Neujahr" by Adel Tawil...
# Done.
# Searching for "Wieder am Leben" by Andreas Bourani...
# Done.
# Searching for "Auf uns" by Andreas Bourani...
# Done.
# Searching for "Alles beim Alten" by Andreas Bourani...
# Done.
# Searching for "Hey" by Andreas Bourani...
# Done.
# ...

# %%
with open('all_without_sections.csv', 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = data[0].keys()
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

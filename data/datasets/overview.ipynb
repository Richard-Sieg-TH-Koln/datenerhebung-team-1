# %%
import pandas as pd
df = pd.read_csv('dataset_cleaned_file_v7.csv')
df
# Out:
#          genre       interpret                 album  release_year
# 0          NaN   Ardian Bujupi                   NaN          2023  \
# 1          NaN   Ardian Bujupi                   NaN          2023
# 2          NaN   Ardian Bujupi                   NaN          2023
# 3          NaN   Ardian Bujupi                   NaN          2022
# 4          NaN   Ardian Bujupi                   NaN          2022
# ...        ...             ...                   ...           ...
# 9645  Schlager  Wolfgang Petry            Achterbahn          2001
# 9646  Schlager  Wolfgang Petry            Achterbahn          2001
# 9647  Schlager  Wolfgang Petry            Achterbahn          2001
# 9648  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 9649  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                            Skena Koh       0  9142376  \
# ...

# %%
duplicates = df[df['song_id'].duplicated()]
print(duplicates)
# Out:
#      genre    interpret        album  release_year
# 5171   NaN  KitschKrieg          NaN          2019  \
# 7256   Rap          Cro  Meine Musik          2011
#
#                          songtitle  decade  song_id
# 5171  Aua, oh oh, Gringo ist sauer       0  4463942  \
# 7256                  Drei Minuten    2010  3197969
#
#                                              full_title
# 5171  Aua, oh oh, Gringo ist sauer by KitschKrieg (F...  \
# 7256       Normale Leute by Savas & Sido (Ft. Marteria)
#
#                 release_date_components_raw release_date_for_display
# 5171  {'year': 2019, 'month': 4, 'day': 12}               2019-04-12  \
# 7256  {'year': 2017, 'month': 8, 'day': 25}               2017-08-25
#
#                                               stats_raw
# 5171  {'unreviewed_annotations': 3, 'hot': False, 'p...  \
# 7256  {'unreviewed_annotations': 4, 'hot': False, 'p...
#
#                                                  lyrics weekday  word_count
# ...

# %%
duplicates = df[df['full_title'].duplicated()]
#duplicates = df[df['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
#      genre    interpret        album  release_year
# 5171   NaN  KitschKrieg          NaN          2019  \
# 7256   Rap          Cro  Meine Musik          2011
#
#                          songtitle  decade  song_id
# 5171  Aua, oh oh, Gringo ist sauer       0  4463942  \
# 7256                  Drei Minuten    2010  3197969
#
#                                              full_title
# 5171  Aua, oh oh, Gringo ist sauer by KitschKrieg (F...  \
# 7256       Normale Leute by Savas & Sido (Ft. Marteria)
#
#                 release_date_components_raw release_date_for_display
# 5171  {'year': 2019, 'month': 4, 'day': 12}               2019-04-12  \
# 7256  {'year': 2017, 'month': 8, 'day': 25}               2017-08-25
#
#                                               stats_raw
# 5171  {'unreviewed_annotations': 3, 'hot': False, 'p...  \
# 7256  {'unreviewed_annotations': 4, 'hot': False, 'p...
#
#                                                  lyrics weekday  word_count
# ...

# %%
df = df.drop_duplicates(['song_id'], keep='first')

# %%
df
# Out:
#          genre       interpret                 album  release_year
# 0          NaN   Ardian Bujupi                   NaN          2023  \
# 1          NaN   Ardian Bujupi                   NaN          2023
# 2          NaN   Ardian Bujupi                   NaN          2023
# 3          NaN   Ardian Bujupi                   NaN          2022
# 4          NaN   Ardian Bujupi                   NaN          2022
# ...        ...             ...                   ...           ...
# 9645  Schlager  Wolfgang Petry            Achterbahn          2001
# 9646  Schlager  Wolfgang Petry            Achterbahn          2001
# 9647  Schlager  Wolfgang Petry            Achterbahn          2001
# 9648  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 9649  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                            Skena Koh       0  9142376  \
# ...

# %%
df.to_csv('dataset_cleaned_file_v8.csv', index=False)

# %%
df = pd.read_csv('dataset_cleaned_file_v8.csv')

# %%
df
# Out:
#          genre       interpret                 album  release_year
# 0          NaN   Ardian Bujupi                   NaN          2023  \
# 1          NaN   Ardian Bujupi                   NaN          2023
# 2          NaN   Ardian Bujupi                   NaN          2023
# 3          NaN   Ardian Bujupi                   NaN          2022
# 4          NaN   Ardian Bujupi                   NaN          2022
# ...        ...             ...                   ...           ...
# 9643  Schlager  Wolfgang Petry            Achterbahn          2001
# 9644  Schlager  Wolfgang Petry            Achterbahn          2001
# 9645  Schlager  Wolfgang Petry            Achterbahn          2001
# 9646  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 9647  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                            Skena Koh       0  9142376  \
# ...

# %%
duplicates = df[df['full_title'].duplicated()]
#duplicates = df[df['song_id'].duplicated()]
# Display the duplicate values
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [genre, interpret, album, release_year, songtitle, decade, song_id, full_title, release_date_components_raw, release_date_for_display, stats_raw, lyrics, weekday, word_count]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('dataset_cleaned_file_v8.csv')

# %%
df["lyrics"]
# Out:
# 0         Ich weiß genau, wie es anfing Hab' mich noch...
# 1         Ey-yeah-yeah-yeah-yeah-yeah Ey-ja-ja-ja-ja-j...
# 2         Blick' durch die Cartier, nice Ferrari, Ital...
# 3         Ruf nur einmal an Und ich fliege für dich üb...
# 4         Komm in mein'n Block (Ey, ey) Aussicht von h...
#                               ...
# 9643     Die Luft ist raus - ich glaub nicht mehr an W...
# 9644     Du wolltest deine Freiheit haben Nun stehst d...
# 9645     Wenn die Sonne untergeht in der Provinz, ho h...
# 9646    Wolfgang Petry - Anfang Vom Ende Lyrics Briefe...
# 9647     Der Albtraum, dem ich entstamme, steht auf Fü...
# Name: lyrics, Length: 9648, dtype: object

# %%
filtered_df = df[df['word_count'] > 500]
filtered_df
# Out:
#      genre          interpret               album  release_year
# 120    NaN        Black Fööss                 NaN             0  \
# 483    NaN            Feuherz                 NaN             0
# 487    NaN            Feuherz                 NaN          2021
# 756    NaN       Jürgen Drews                 NaN          2020
# 1644   NaN        Stefan Raab                 NaN          2001
# 2479   NaN  Absolute Beginner                 NaN          2016
# 2491   NaN  Absolute Beginner                 NaN          2000
# 2645   NaN          Dendemann                 NaN          2016
# 2646   NaN          Dendemann                 NaN          2016
# 2712   NaN          Eko Fresh                 NaN          2020
# 2940   NaN           Kollegah                 NaN          2022
# 2951   NaN           Kollegah                 NaN          2022
# 2952   NaN           Kollegah                 NaN          2022
# 3054   NaN          Max Herre                 NaN          2013
# ...

# %%
df
# Out:
#          genre       interpret                 album  release_year
# 0          NaN   Ardian Bujupi                   NaN          2023  \
# 1          NaN   Ardian Bujupi                   NaN          2023
# 2          NaN   Ardian Bujupi                   NaN          2023
# 3          NaN   Ardian Bujupi                   NaN          2022
# 4          NaN   Ardian Bujupi                   NaN          2022
# ...        ...             ...                   ...           ...
# 9643  Schlager  Wolfgang Petry            Achterbahn          2001
# 9644  Schlager  Wolfgang Petry            Achterbahn          2001
# 9645  Schlager  Wolfgang Petry            Achterbahn          2001
# 9646  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
# 9647  Schlager  Wolfgang Petry  Kein Grund zur Panik          2003
#
#                              songtitle  decade  song_id
# 0                            Skena Koh       0  9142376  \
# ...

# %%
nan_count = df["release_date_components_raw"].isna().sum()
print(nan_count)
# Out:
# 1921

# %%
df.interpret.sort_values().unique()
# Out:
# array(['01099', '18 Karat', '187 Straßenbande', '257ers', '2raumwohnung',
#        'Absolute Beginner', 'Adel Tawil', 'Alligatoah', 'Andrea Berg',
#        'Andreas Bourani', 'Andreas Gabalier', 'AnnenMayKantereit',
#        'Annett Louisan', 'Antilopen Gang', 'Apache 207', 'Ardian Bujupi',
#        'Asche', 'Azad', 'Azet', 'BHZ', 'BRKN', 'Bass Sultan Hengzt',
#        'Bausa', 'Beatrice Egli', 'Beginner', 'Bela B', 'Ben Zucker',
#        'Bilderbuch', 'Bizzy Montana', 'Black Fööss', 'Blümchen', 'Bosse',
#        'Brings', 'Broilers', 'Bushido', 'Capital Bra', 'Capo', 'Casper',
#        'Cat Ballou', 'Celo & Abdi', 'Chakuza', 'Christian Anders',
#        'Christina Stürmer', 'Clueso', 'Costa Cordalis', 'Cro',
#        'Culcha Candela', 'DCVDNS', 'DJ Tomekk', 'DJ Ötzi',
#        'Daniel Sommer', 'Dardan', 'Deichkind', 'Dendemann', 'Die Atzen',
#        'Die Fantastischen Vier', 'Die Flippers', 'Die Lochis',
#        'Die Orsons', 'Die Prinzen', 'Die Ärzte', 'Dieter Thomas Kuhn',
# ...

# %%
unique_artists_count = df['interpret'].nunique()
print("Number of unique artists:", unique_artists_count)
# Out:
# Number of unique artists: 260

# %%
import pandas as pd

# %%
df = pd.read_csv('albums_songs_de_dedub.csv')

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0 Artist  Artist_ID        Album  Album_ID
# 0                 7           7   1099     209826        10999    831505  \
# 1                 8           8   1099     209826        10999    831505
# 2                 9           9   1099     209826        10999    831505
# 3                10          10   1099     209826        10999    831505
# 4                12          12   1099     209826        10999    831505
# ...             ...         ...    ...        ...          ...       ...
# 23700         93617       93617  t-low       9229  Tyskie (EP)    553779
# 23701         93618       93618  t-low       9229  Tyskie (EP)    553779
# 23702         93619       93619  t-low       9229  Tyskie (EP)    553779
# 23703         93620       93620  t-low       9229  Tyskie (EP)    553779
# 23704         93621       93621  t-low       9229  Tyskie (EP)    553779
#
#            Release_Date           Title
# 0      October 29, 2021   INTRO (10999)  \
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)

# %%
df
# Out:
#       Artist  Artist_ID        Album  Album_ID      Release_Date
# 0       1099     209826        10999    831505  October 29, 2021  \
# 1       1099     209826        10999    831505  October 29, 2021
# 2       1099     209826        10999    831505  October 29, 2021
# 3       1099     209826        10999    831505  October 29, 2021
# 4       1099     209826        10999    831505  October 29, 2021
# ...      ...        ...          ...       ...               ...
# 23700  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23701  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23702  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23703  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23704  t-low       9229  Tyskie (EP)    553779    August 2, 2019
#
#                 Title                                   Full_Title  Song_ID
# 0       INTRO (10999)                 INTRO (10999) by King Khalil  7337100  \
# ...

# %%
df.to_csv('clean_dataset.csv', index=False)

# %%
a = pd.read_csv('clean_dataset.csv')
a
# Out:
#       Artist  Artist_ID        Album  Album_ID      Release_Date
# 0       1099     209826        10999    831505  October 29, 2021  \
# 1       1099     209826        10999    831505  October 29, 2021
# 2       1099     209826        10999    831505  October 29, 2021
# 3       1099     209826        10999    831505  October 29, 2021
# 4       1099     209826        10999    831505  October 29, 2021
# ...      ...        ...          ...       ...               ...
# 23700  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23701  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23702  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23703  t-low       9229  Tyskie (EP)    553779    August 2, 2019
# 23704  t-low       9229  Tyskie (EP)    553779    August 2, 2019
#
#                 Title                                   Full_Title  Song_ID
# 0       INTRO (10999)                 INTRO (10999) by King Khalil  7337100  \
# ...

# %%
import lyricsgenius
import pandas as pd

# %%
token = "aCR_2MFW9c27A8yjxOWlsCfqywd5w1KzwBZJMqncj4psGS0pPdcGzIv05TfkrKIG"
genius = lyricsgenius.Genius(token, remove_section_headers=True, timeout=10000, retries=5)

# %%
artist_test_df = pd.read_csv("musicbrainz_country_de.csv")

# %%
def search_lyrics_by_artist(artist_name):
    # Search artist from musicbrainz_country_de
    # Search for the latest 5 released songs
    artist = genius.search_artist(artist_name, sort="release_date", max_songs=5)
    if artist is not None:
        # List to save the data -> Later transformed to dataframe
        data = []
        # Generate a list of song titles for each artist
        titles = [song.title for song in artist.songs]
        for title in titles:            
            # Search for specific song by title and artist
            song = genius.search_song(title, artist_name)
            if song is not None and song._body['language'] == "de":
                # Append data to the list for each song
                data.append([artist_name,
                            title,
                            song._body['release_date_for_display'],
                            song._body['language'],
                            song.lyrics])
            else:
                pass

        return data
    
    else:
        pass


# Create empty DataFrame to store the data from the data list
df = pd.DataFrame(columns=["Artist", "Song", "Language", "Release_Date", "Lyrics"])


# Input artist name
for name in artist_test_df["Overview"]:
    artist_name = name

    # Call function search_lyrics_by_artist
    lyrics_data = search_lyrics_by_artist(artist_name)
    if lyrics_data is not None:
        # Store the data in the DataFrame
        df = df.append(pd.DataFrame(lyrics_data, columns=["Artist", "Song", "Language", "Release_Date", "Lyrics"]), ignore_index=True)
# Out:
# Searching for songs by Sido...
#
# Song 1: "Over $112M Lost to Cryptocurrency Investment Scam Recovered by RSB"
# Song 2: "3 Monde"
# Song 3: "Wenig königlich"
# Song 4: "Rollender Stein"
# Song 5: "Intro (PAUL)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Over $112M Lost to Cryptocurrency Investment Scam Recovered by RSB" by Sido...
# Done.
# Searching for "3 Monde" by Sido...
# Done.
# Searching for "Wenig königlich" by Sido...
# Done.
# Searching for "Rollender Stein" by Sido...
# Done.
# Searching for "Intro (PAUL)" by Sido...
# Done.
# Searching for songs by Otttoo Sendler Test123...
# C:\Users\User\AppData\Local\Temp\ipykernel_8424\2263996053.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(lyrics_data, columns=["Artist", "Song", "Language", "Release_Date", "Lyrics"]), ignore_index=True)
# No results found for 'Otttoo Sendler Test123'.
# Searching for songs by Clueso...
#
# "Paris (aus ”Sing meinen Song, Vol. 10") I" is not valid. Skipping.
# "Ich hab Dich nicht mehr zu verlier’n (aus ”Sing meinen Song, Vol. 10")" is not valid. Skipping.
# "Play With Fire (aus ”Sing meinen Song, Vol. 10") I" is not valid. Skipping.
# "Play With Fire (aus ”Sing meinen Song, Vol. 10")" is not valid. Skipping.
# "Heimweh nach wir (aus ”Sing meinen Song, Vol. 10")" is not valid. Skipping.
# Song 1: "Leichtes Gepäck (aus “Sing meinen Song, Vol. 10”)"
# Song 2: "Love to Go (Aus „Sing meinen Song, Vol. 9“)"
# Song 3: "Zu jung (Aus „Sing meinen Song, Vol. 9“)"
# Song 4: "Anlauf nehmen (Aus „Sing meinen Song, Vol. 9“)"
# Song 5: "Tanz aus der Reihe (Aus „Sing meinen Song, Vol. 9“)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Leichtes Gepäck (aus “Sing meinen Song, Vol. 10”)" by Clueso...
# Done.
# Searching for "Love to Go (Aus „Sing meinen Song, Vol. 9“)" by Clueso...
# Done.
# Searching for "Zu jung (Aus „Sing meinen Song, Vol. 9“)" by Clueso...
# Done.
# Searching for "Anlauf nehmen (Aus „Sing meinen Song, Vol. 9“)" by Clueso...
# Done.
# Searching for "Tanz aus der Reihe (Aus „Sing meinen Song, Vol. 9“)" by Clueso...
# Done.
# Searching for songs by Andrea Berg...
# C:\Users\User\AppData\Local\Temp\ipykernel_8424\2263996053.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(lyrics_data, columns=["Artist", "Song", "Language", "Release_Date", "Lyrics"]), ignore_index=True)
# Song 1: "Viel zu schön um wahr zu sein - Jojo Fox Mix"
# Song 2: "Viel zu schön um wahr zu sein - Jojo Dance Mix"
# Song 3: "Viel zu schön um wahr zu sein"
# Song 4: "Du hast mich tausendmal belogen #2022"
# Song 5: "SOS an Wolke 7"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Viel zu schön um wahr zu sein - Jojo Fox Mix" by Andrea Berg...
# Done.
# Searching for "Viel zu schön um wahr zu sein - Jojo Dance Mix" by Andrea Berg...
# Done.
# Searching for "Viel zu schön um wahr zu sein" by Andrea Berg...
# Done.
# Searching for "Du hast mich tausendmal belogen #2022" by Andrea Berg...
# Done.
# Searching for "SOS an Wolke 7" by Andrea Berg...
# Done.
# C:\Users\User\AppData\Local\Temp\ipykernel_8424\2263996053.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(lyrics_data, columns=["Artist", "Song", "Language", "Release_Date", "Lyrics"]), ignore_index=True)

# %%
df.head(20)
# Out:
#          Artist                                               Song  \
# 0          Sido                                            3 Monde
# 1          Sido                                    Wenig königlich
# 2          Sido                                    Rollender Stein
# 3          Sido                                       Intro (PAUL)
# 4        Clueso  Leichtes Gepäck (aus “Sing meinen Song, Vol. 10”)
# 5        Clueso        Love to Go (Aus „Sing meinen Song, Vol. 9“)
# 6        Clueso           Zu jung (Aus „Sing meinen Song, Vol. 9“)
# 7        Clueso     Anlauf nehmen (Aus „Sing meinen Song, Vol. 9“)
# 8        Clueso  Tanz aus der Reihe (Aus „Sing meinen Song, Vol...
# 9   Andrea Berg       Viel zu schön um wahr zu sein - Jojo Fox Mix
# 10  Andrea Berg     Viel zu schön um wahr zu sein - Jojo Dance Mix
# 11  Andrea Berg                      Viel zu schön um wahr zu sein
# 12  Andrea Berg              Du hast mich tausendmal belogen #2022
# 13  Andrea Berg                                     SOS an Wolke 7
#
#              Language Release_Date  \
# 0    December 9, 2022           de
# 1    December 9, 2022           de
# 2    December 9, 2022           de
# 3    December 9, 2022           de
# 4      April 26, 2023           de
# 5        May 13, 2022           de
# 6        May 13, 2022           de
# 7        May 10, 2022           de
# 8         May 3, 2022           de
# 9   February 24, 2023           de
# 10  February 24, 2023           de
# 11   October 28, 2022           de
# 12      July 29, 2022           de
# 13      July 29, 2022           de
#
#                                                Lyrics
# 0   6 Contributors3 Monde Lyrics\n\nKann weniger, ...
# 1   6 ContributorsWenig königlich Lyrics\n\nWas ic...
# 2   4 ContributorsRollender Stein Lyrics\n\nTut mi...
# 3   7 ContributorsIntro (PAUL) Lyrics\n\nMorgen\nM...
# 4   3 ContributorsLeichtes Gepäck (aus “Sing meine...
# 5   2 ContributorsLove to Go (Aus „Sing meinen Son...
# 6   2 ContributorsZu jung (Aus „Sing meinen Song, ...
# 7   2 ContributorsAnlauf nehmen (Aus „Sing meinen ...
# 8   3 ContributorsTanz aus der Reihe (Aus „Sing me...
# 9   1 ContributorViel zu schön um wahr zu sein - J...
# 10  1 ContributorViel zu schön um wahr zu sein - J...
# 11  1 ContributorViel zu schön um wahr zu sein Lyr...
# 12  3 ContributorsDu hast mich tausendmal belogen ...
# 13  2 ContributorsSOS an Wolke 7 Lyrics\n\nSOS an ...

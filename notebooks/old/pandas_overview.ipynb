# %%
import pandas as pd
all_w_sections = pd.read_csv('all_with_sections.csv')

# %%
all_w_sections
# Out:
#          genre       interpret    album  release_year  \
# 0          Pop      Adel Tawil   Lieder          2013
# 1          Pop      Adel Tawil   Lieder          2013
# 2          Pop      Adel Tawil   Lieder          2013
# 3          Pop      Adel Tawil   Lieder          2013
# 4          Pop      Adel Tawil   Lieder          2013
# ...        ...             ...      ...           ...
# 4632  Schlager  Wolfgang Petry  Typisch          2004
# 4633  Schlager  Wolfgang Petry  Typisch          2004
# 4634  Schlager  Wolfgang Petry  Typisch          2004
# 4635  Schlager  Wolfgang Petry  Typisch          2004
# 4636  Schlager  Wolfgang Petry  Typisch          2004
#
#                                songtitle  decade  \
# 0                               Immer da    2010
# 1                         Wenn Du liebst    2010
# 2                                 Lieder    2010
# 3                                 Weinen    2010
# 4                           Unter Wasser    2010
# ...

# %%
all_wO_sections = pd.read_csv('all_without_sections.csv')

# %%
all_wO_sections
# Out:
#          genre       interpret    album  release_year  \
# 0          Pop      Adel Tawil   Lieder          2013
# 1          Pop      Adel Tawil   Lieder          2013
# 2          Pop      Adel Tawil   Lieder          2013
# 3          Pop      Adel Tawil   Lieder          2013
# 4          Pop      Adel Tawil   Lieder          2013
# ...        ...             ...      ...           ...
# 4632  Schlager  Wolfgang Petry  Typisch          2004
# 4633  Schlager  Wolfgang Petry  Typisch          2004
# 4634  Schlager  Wolfgang Petry  Typisch          2004
# 4635  Schlager  Wolfgang Petry  Typisch          2004
# 4636  Schlager  Wolfgang Petry  Typisch          2004
#
#                                songtitle  decade  \
# 0                               Immer da    2010
# 1                         Wenn Du liebst    2010
# 2                                 Lieder    2010
# 3                                 Weinen    2010
# 4                           Unter Wasser    2010
# ...

# %%
dummy_527 = pd.read_csv('dummy_527_songs.csv')

# %%
dummy_527
# Out:
#     genre   interpret      album  release_year       songtitle  decade  \
# 0     Pop  Adel Tawil     Lieder          2013        Immer da    2010
# 1     Pop  Adel Tawil     Lieder          2013  Wenn Du liebst    2010
# 2     Pop  Adel Tawil     Lieder          2013          Lieder    2010
# 3     Pop  Adel Tawil     Lieder          2013          Weinen    2010
# 4     Pop  Adel Tawil     Lieder          2013    Unter Wasser    2010
# ..    ...         ...        ...           ...             ...     ...
# 522   Pop      Namika  Que Walou          2018          Zirkus    2010
# 523   Pop        Nena       Nena          1983            Kino    1980
# 524   Pop        Nena       Nena          1983        Indianer    1980
# 525   Pop        Nena       Nena          1983        Vollmond    1980
# 526   Pop        Nena       Nena          1983    Nur geträumt    1980
#
#                                                 lyrics
# 0    Immer da Lyrics[Songtext zu „Immer da“]\r\n\r\...
# ...
